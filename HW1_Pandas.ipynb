# %% [markdown]
# ## Write Custom Function to Compute Histogram for a Numerical Array
#
# - You can use numpy
#
# - Your function takes two arguments: 1- list 2- interval
#
# - Your function would return a dictionary with intervals as keys and how many of elements in list are in the intervals as values

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./Datasets/titanic.csv')

# %%
# histogram function

def custom_hist(ls, interval):
    hist_ls_dict = dict()
    min_ls = np.min(ls)
    max_ls = np.max(ls)
    I = np.ceil((max_ls - min_ls) / interval)
    
    start = min_ls
    
    for i in range(interval):
        hist_ls_dict[str((start, start + I))] = len(ls[(ls >= start) & (ls < start + I)]) 
        start += I
    
    # ----rounded up x-values----
    # for j in range(int(min_ls), int(max_ls + I), int(I)):
        # hist_ls_dict[str((j, j+I))] = len(ls[(ls >= j) & (ls < j + I)])    

    return hist_ls_dict
        
print(custom_hist(df['Age'].dropna().values, 16))
# Out:
# {'(0.42, 5.42)': 44, '(5.42, 10.42)': 20, '(10.42, 15.42)': 19, '(15.42, 20.42)': 96, '(20.42, 25.42)': 122, '(25.42, 30.42)': 108, '(30.42, 35.42)': 88, '(35.42, 40.42)': 67, '(40.42, 45.42)': 47, '(45.42, 50.42)': 39, '(50.42, 55.42)': 24, '(55.42, 60.42)': 18, '(60.42, 65.42)': 14, '(65.42, 70.42)': 3, '(70.42, 75.42)': 4, '(75.42, 80.42)': 1}

# %% [markdown]
# ## For visualization part, you should elaborate on the following

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.xticks(rotation=45)

hist_dict = custom_hist(df['Age'].dropna().values, 16)
plt.bar(hist_dict.keys(), hist_dict.values())
plt.show()

# %%
# matplotlib's hist diagram
plt.hist(df['Age'].dropna(), 16)
# Out:
# (array([ 44.,  20.,  19.,  96., 122., 108.,  88.,  67.,  47.,  39.,  24.,
#          18.,  14.,   3.,   4.,   1.]),
#  array([ 0.42   ,  5.39375, 10.3675 , 15.34125, 20.315  , 25.28875,
#         30.2625 , 35.23625, 40.21   , 45.18375, 50.1575 , 55.13125,
#         60.105  , 65.07875, 70.0525 , 75.02625, 80.     ]),
#  <a list of 16 Patch objects>)

# %% [markdown]
# ## Q2: How we can plot histogram of Age for female and male with legend?

# %%
df.groupby('Sex')['Age'].plot(kind='hist', bins=16, alpha=0.5, legend=True)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object
